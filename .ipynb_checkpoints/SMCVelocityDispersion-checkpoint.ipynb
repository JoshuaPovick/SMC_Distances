# %%
##################################
### Import the usual libraries ###
##################################

### Numpy
import numpy as np

### Astropy
import astropy

#Astropy FITS/Table handling
from astropy.io import fits, ascii
from astropy.table import Table, Column

#astropy coorindates/units
from astropy.coordinates import SkyCoord
import astropy.constants as const
import astropy.units as u

### Pandas
# import pandas as pd

### Matplotlib
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 18}) #make plots more readable
import matplotlib.patches as mpatches
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator
from matplotlib.offsetbox import AnchoredText

# ### Yumi's RA/DEC ---> Magellanic Stream Coorindates
# import MagellanicStream as ms

# ### Functions used in this code
# import age_functions as afunc

## Stuff Writtten by A Really Cool Professor
import dlnpyutils as dlpu

###
import linearfitting as linfit
import geometry as geo

import mlefitting as mlefit
import olsfitting as olsfit
import utilities as util

### Other
import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm_notebook

### Age of Universe
H0 = 74.03*(u.km/u.s)/u.Mpc
hertz = H0.to(u.km/u.s/u.pc).to(u.km/u.s/u.km)
tage = (1/hertz).to(u.yr)
ageU = tage.value

# %%
#######################
### Import SMC Data ###
#######################

#total number 1225
smc = fits.getdata('/Users/joshpovick/Research/SMC_Gradients/smc_rgbmembers.r13-l33-58932beta.fits.gz') 

cln = np.where((smc['FE_H']>-9999.0)&(smc['AK_TARG']>-9999.0)&(smc['LOGG']>0.0)&
               (smc['FE_H_ERR']>-90.0)&(smc['C_FE']>-9999.0)&(smc['N_FE']>-9999.0))

#total number 990
smc = smc[cln]

## Find Bloop
bloop = np.where((smc['H']<=13.25)&(smc['J']-smc['K']<=0.95)&(smc['TEFF']>=4175))
bloop_cut = []
for i in range(len(smc)):
    if i not in np.squeeze(bloop).tolist():
        bloop_cut.append(i)
        
smc_nobloop = smc[bloop_cut]

# %%
####################################
### Gaia Query Using Online Form ###
####################################

# (00:52:44, −72:49:42) Used in SMASH
center = SkyCoord('00:52:44 -72:49:42', unit=(u.hourangle, u.deg))

print('''Cone search center: {} with radius 6.5 deg'''.format(center))

smc_gaia = fits.getdata('smc_apogee-result.fits.gz')
cln = np.where((smc_gaia['astrometric_excess_noise']<1.0)&(np.isfinite(smc_gaia['phot_g_mean_mag'])==True)&
               (np.isfinite(smc_gaia['phot_g_mean_mag'])==True)&(np.isfinite(smc_gaia['phot_bp_mean_mag'])==True)&
               (np.isfinite(smc_gaia['phot_rp_mean_mag'])==True)&(smc_gaia['parallax']<0.2)&
               (smc_gaia['parallax']>-0.2)&(smc_gaia['pmra']>=-3.0)&(smc_gaia['pmra']<=3.0)&
               (smc_gaia['pmdec']>=-3.0)&(smc_gaia['pmdec']<=3.0)&(smc_gaia['phot_g_mean_flux_over_error']>5.0)&
               (smc_gaia['phot_bp_mean_flux_over_error']>5.0)&(smc_gaia['phot_rp_mean_flux_over_error']>5.0))
smc_gaia = smc_gaia[cln]

# cuts from  

# @ARTICLE{2020MNRAS.tmp.3030O,
#        author = {{Omkumar}, Abinaya O. and {Subramanian}, Smitha and
#          {Niederhofer}, Florian and {Diaz}, Jonathan and {Cioni}, Maria-Rosa L. and
#          {El Youssoufi}, Dalal and {Bekki}, Kenji and {de Grijs}, Richard and
#          {van Loon}, Jacco Th},
#         title = "{Gaia view of a stellar sub-structure in front of the Small Magellanic Cloud}",
#       journal = {\mnras},
#      keywords = {Magellanic Clouds, galaxies: interactions, proper motions, stars: kinematics and dynamics, Astrophysics - Astrophysics of Galaxies},
#          year = 2020,
#         month = oct,
#           doi = {10.1093/mnras/staa3085},
# archivePrefix = {arXiv},
#        eprint = {2010.02687},
#  primaryClass = {astro-ph.GA},
#        adsurl = {https://ui.adsabs.harvard.edu/abs/2020MNRAS.tmp.3030O},
#       adsnote = {Provided by the SAO/NASA Astrophysics Data System}
# }
# Out:
# Cone search center: <SkyCoord (ICRS): (ra, dec) in deg
#     (13.18333333, -72.82833333)> with radius 6.5 deg

# %%
# Distance Modulus 18.99 +/- .10 

# @ARTICLE{2000A&A...359..601C,
#        author = {{Cioni}, M. -R.~L. and {van der Marel}, R.~P. and {Loup}, C. and
#          {Habing}, H.~J.},
#         title = "{The tip of the red giant branch and distance of the Magellanic Clouds: results from the DENIS survey}",
#       journal = {\aap},
#      keywords = {METHODS: STATISTICAL, STARS: EVOLUTION, GALAXIES: MAGELLANIC CLOUDS, GALAXIES: DISTANCES AND REDSHIFTS, Astrophysics},
#          year = 2000,
#         month = jul,
#        volume = {359},
#         pages = {601-614},
# archivePrefix = {arXiv},
#        eprint = {astro-ph/0003223},
#  primaryClass = {astro-ph},
#        adsurl = {https://ui.adsabs.harvard.edu/abs/2000A&A...359..601C},
#       adsnote = {Provided by the SAO/NASA Astrophysics Data System}
# }

# %%
#########################
### Import Isochrones ###
#########################

parsecall = ascii.read('/Users/joshpovick/Research/SMC_Gradients/parsec3_3.dat', \
                    format='basic', delimiter='\s')

parsec = parsecall[np.where(parsecall['label']==3)]

# parsec9351010 = ascii.read('/Users/joshpovick/Desktop/Research/SMC_Gradients/parsec3_49351010.dat', \
#                     format='basic', delimiter='\s')

# %%
set(smc['FIELD'])
# Out:
# {'47TUC', 'N362', 'SMC1', 'SMC2', 'SMC3', 'SMC4', 'SMC5', 'SMC6', 'SMC7'}

# %%
field = np.array(['47TUC', 'N362', 'SMC1', 'SMC2', 'SMC3', 'SMC4', 'SMC5', 'SMC6', 'SMC7'])

ra = []
dec = []
for i in range(len(field)):
    field_cut = np.where(smc['FIELD']==field[i])
    ra.append(np.median(smc[field_cut]['RA']))
    dec.append(np.median(smc[field_cut]['DEC']))

ra = np.asarray(ra)
dec = np.asarray(dec)
radius = 0.95*np.ones(len(field))

tab = Table([field, ra, dec, radius],names=('FIELD', 'RA', 'DEC', 'RADIUS'))
# tab.show_in_browser(jsviewer=True)

# %%
################
### smc_nobloop Map ###
###############

### Map

from scipy.interpolate import griddata

radius = smc_nobloop['SMCRAD']*1.05

xx,yy = np.meshgrid(np.linspace(np.min(smc_nobloop['RA']),np.max(smc_nobloop['RA']),100),
                    np.linspace(np.min(smc_nobloop['DEC']),np.max(smc_nobloop['DEC']),100))

points = np.array([smc_nobloop['RA'],smc_nobloop['DEC']]).T

grid_z0 = griddata(points, radius, (xx, yy), method='cubic')

field_color = []
for i in range(len(smc_nobloop)):
    if smc_nobloop['FIELD'][i] == '47TUC':
        field_color.append(8.0)
    if smc_nobloop['FIELD'][i] == 'N362':
        field_color.append(9.0)
    if smc_nobloop['FIELD'][i] == 'SMC1':
        field_color.append(1.0)
    if smc_nobloop['FIELD'][i] == 'SMC2':
        field_color.append(2.0)
    if smc_nobloop['FIELD'][i] == 'SMC3':
        field_color.append(3.0)
    if smc_nobloop['FIELD'][i] == 'SMC4':
        field_color.append(4.0)
    if smc_nobloop['FIELD'][i] == 'SMC5':
        field_color.append(5.0)
    if smc_nobloop['FIELD'][i] == 'SMC6':
        field_color.append(6.0)
    if smc_nobloop['FIELD'][i] == 'SMC7':
        field_color.append(7.0)

matplotlib.rcParams.update({'font.size': 30})
# plt.figure(figsize=[12,12])

fig, ax = plt.subplots(figsize=[12,10])

plt.scatter(smc_nobloop['RA'],smc_nobloop['DEC'],c=field_color,cmap='Set1')
plt.colorbar()

plt.scatter(13.18333333,-72.82833333,marker='*',s=500)

for i in range(len(tab)):
    plt.scatter(tab['RA'][i],tab['DEC'][i],marker='*',s=200,c='r')

plt.xlim(0,35)
plt.ylim(-78,-66)

plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()

CS = plt.contour(xx,yy,grid_z0*1.05,levels=[1,2,3,4,5,6],colors='k')
plt.clabel(CS,fmt='%2.1d',colors='k',fontsize=25)#,manual=locations)

# plt.xticks([-8,-4.0,0,4.0,8])
# plt.yticks([-8,-4.0,0,4.0,8])

plt.xlabel(r'$\alpha$ [deg]')
plt.ylabel(r'$\delta$ [deg]')

plt.show()

# %%
tab.write('APOGEEfieldcenters.fits', format='fits', overwrite=True)

# %%
tab
# Out:
# <Table length=9>
# FIELD         RA                DEC          RADIUS
#  str5      float64            float64       float64
# ----- ------------------ ------------------ -------
# 47TUC          7.2804145         -72.385277    0.95
#  N362 14.670836000000001           -71.4291    0.95
#  SMC1           6.055699         -76.913269    0.95
#  SMC2          10.423217         -67.981483    0.95
#  SMC3          11.485583        -73.2748565    0.95
#  SMC4          16.482166         -75.364868    0.95
#  SMC5          19.219679         -73.026657    0.95
#  SMC6 24.026373999999997        -71.2725145    0.95
#  SMC7         30.4412785 -73.38494850000001    0.95

# %%
### Individual APOGEE Fields

tuc47_ind = np.where(smc_nobloop['FIELD']=='47TUC')
tuc47 = smc_nobloop[tuc47_ind]

n362_ind = np.where(smc_nobloop['FIELD']=='N362')
n362 = smc_nobloop[n362_ind]

smc1_ind = np.where(smc_nobloop['FIELD']=='SMC1')
smc1 = smc_nobloop[smc1_ind]

smc2_ind = np.where(smc_nobloop['FIELD']=='SMC2')
smc2 = smc_nobloop[smc2_ind]

smc3_ind = np.where(smc_nobloop['FIELD']=='SMC3')
smc3 = smc_nobloop[smc3_ind]

smc4_ind = np.where(smc_nobloop['FIELD']=='SMC4')
smc4 = smc_nobloop[smc4_ind]

smc5_ind = np.where(smc_nobloop['FIELD']=='SMC5')
smc5 = smc_nobloop[smc5_ind]

smc6_ind = np.where(smc['FIELD']=='SMC6')
smc6 = smc_nobloop[smc6_ind]

smc7_ind = np.where(smc_nobloop['FIELD']=='SMC7')
smc7 = smc_nobloop[smc7_ind]

# %% [markdown]
# <font size='45'>
#     <b>
#         Calculate Dispersion
#     </b>
# </font>

# %%
# -take a single star in a field go through the steps of calculating the distance
# -go through the exact steps again but add a random number to the transverse velocity.  
# You want to pull a random number from a Gaussian distribution with a standard deviation of 27 km/s.
# np.random.randn(1)*27.0
# -repeat this ~100 times
# -look at the distribution (e.g., histogram) of the resulting distances.  what is the standard deviation?  
# this gives us the additional uncertainty in the distances due to the internal motions.

# %%
#################
### Fucntions ###
#################

def dist(mu,mu0,d0):
    '''
    Calculate the kinematic distance to a star assuming all stars have the same tangential velocity
    
    Inputs:
    ------
        mu: proper motion magnitude
        d0: ref distance
        mu0: ref proper motion magnitude in units of mu
        
    Output:
    ------
        d: distance to star in the same units of d0
    '''
    
    d = d0*np.divide(mu0,mu)
    
    return d

# %%
dev = []
for i in range(100):
    dev.append(util.add_noise(0,27)*1000/(4.74*60000))
    
plt.figure(figsize=[15,10])
plt.hist(dev)
plt.xlabel(r'$\delta\mu_0$ [mas/yr]')
plt.show()
print(util.mad(dev))
# Out:
# 0.06056990204943565

# %%
# Out:
# ColDefs(
#     name = 'APSTAR_ID'; format = '46A'
#     name = 'TARGET_ID'; format = '36A'
#     name = 'ASPCAP_ID'; format = '48A'
#     name = 'FILE'; format = '34A'
#     name = 'APOGEE_ID'; format = '18A'
#     name = 'TELESCOPE'; format = '6A'
#     name = 'LOCATION_ID'; format = 'J'
#     name = 'FIELD'; format = '5A'
#     name = 'J'; format = 'E'
#     name = 'J_ERR'; format = 'E'
#     name = 'H'; format = 'E'
#     name = 'H_ERR'; format = 'E'
#     name = 'K'; format = 'E'
#     name = 'K_ERR'; format = 'E'
#     name = 'RA'; format = 'D'
#     name = 'DEC'; format = 'D'
#     name = 'GLON'; format = 'D'
#     name = 'GLAT'; format = 'D'
#     name = 'APOGEE_TARGET1'; format = 'J'
#     name = 'APOGEE_TARGET2'; format = 'J'
#     name = 'APOGEE_TARGET3'; format = 'J'
#     name = 'APOGEE2_TARGET1'; format = 'J'
#     name = 'APOGEE2_TARGET2'; format = 'J'
#     name = 'APOGEE2_TARGET3'; format = 'J'
#     name = 'TARGFLAGS'; format = '45A'
# ...

# %%
rc_cut = np.where((smc_gaia['bp_rp']>0.65)&(smc_gaia['bp_rp']<1.25)&(smc_gaia['phot_g_mean_mag']>18.8)
                  &(smc_gaia['phot_g_mean_mag']<19.7))
rc_gaia = smc_gaia[rc_cut]

d0 = 60000 #10**(18.99/5.+1) #pc
rc_pmmag = np.sqrt(rc_gaia['pmra']**2+rc_gaia['pmdec']**2)
rc_pmmag_error = util.mad(rc_pmmag)
# rc_pmmag_err = 2.*np.sqrt((rc_gaia['pmra_error']**2)*rc_gaia['pmra']**2+
#                           (rc_gaia['pmdec_error']**2)*rc_gaia['pmdec']**2)

dist_dist = []
dist_dist_nopm = []
for i in tqdm_notebook(range(len(smc_nobloop)),desc='Star'):
    mu = np.sqrt(smc_nobloop['GAIA_PMRA'][i]**2+smc_nobloop['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
             1000*util.add_noise(0,27)/(4.74*mu))
        d_nopm = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    dist_dist.append(calc_dist)
    dist_dist_nopm.append(calc_dist_nopm)
# Out:
# ...
# ...
# ...

# %%
dis = []
dis_err = []
dis_nopm = []
dis_nopm_err = []

for i in range(len(dist_dist)):
    dis.append(np.median(dist_dist[i]))
    dis_err.append(util.mad(dist_dist[i]))
    dis_nopm.append(np.median(dist_dist_nopm[i]))
    dis_nopm_err.append(util.mad(dist_dist_nopm[i]))

plt.figure(figsize=[12,10])
plt.hist(np.asarray(dis)/1000.,histtype='step',density=True,color='k',label='tan+pm')
plt.hist(np.asarray(dis_nopm)/1000.,histtype='step',density=True,color='r',label='tan')
plt.legend()

plt.axvline(50,ls='--',c='b')
plt.axvline(60,ls='--',c='b')
plt.axvline(70,ls='--',c='b')

plt.title(r'Total SMC')
plt.show()

print('d0: {:.3f} pc'.format(d0))
print('  ')
print('--- Vary Tan Vel + Proper Motion ---')
print('Median {:.3f} +/- {:.3f} pc'.format(np.median(dis),util.mad(dis)))
print('Mean {:.3f} +/- {:.3f} pc'.format(np.mean(dis),np.std(dis)))
print('  ')
print('--- Vary Tan Vel ---')
print('Median {:.3f} +/- {:.3f} pc'.format(np.median(dis_nopm),util.mad(dis_nopm)))
print('Mean {:.3f} +/- {:.3f} pc'.format(np.mean(dis_nopm),np.std(dis_nopm)))

# plt.hist(np.asarray(dis_err)/1000.,histtype='step',density=True,color='k')
# plt.title(r'Distance Error')
# plt.show()

# # print('d0: {:.3f} kpc'.format(d0))
# print('Median {:.3f} +/- {:.3f} pc'.format(np.median(dis_err),util.mad(dis_err)))
# print('Mean {:.3f} +/- {:.3f} pc'.format(np.mean(dis_err),np.std(dis_err)))
# Out:
# d0: 60000.000 pc
#
# --- Vary Tan Vel + Proper Motion ---
# Median 63473.838 +/- 6409.096 pc
# Mean 63706.758 +/- 9216.456 pc
#
# --- Vary Tan Vel ---
# Median 63543.095 +/- 6457.082 pc
# Mean 63645.872 +/- 8979.557 pc

# %%
smc7_dist = []
smc7_dist_nopm = []
for i in tqdm_notebook(range(len(smc7)),desc='Star'):
    mu = np.sqrt(smc7['GAIA_PMRA'][i]**2+smc7['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc7_dist.append(calc_dist)
    smc7_dist_nopm.append(calc_dist_nopm)
    
smc7dis = []
smc7dis_err = []
smc7dis_nopm = []
smc7dis_nopm_err = []

for i in range(len(smc7_dist)):
    smc7dis.append(np.median(smc7_dist[i]))
    smc7dis_err.append(util.mad(smc7_dist[i]))
    smc7dis_nopm.append(np.median(smc7_dist_nopm[i]))
    smc7dis_nopm_err.append(util.mad(smc7_dist_nopm[i]))

# %% [markdown]
# # Field By Field

# %%
### 47TUC
tuc47_dist = []
tuc47_dist_nopm = []
for i in tqdm_notebook(range(len(tuc47)),desc='Star'):
    mu = np.sqrt(tuc47['GAIA_PMRA'][i]**2+tuc47['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    tuc47_dist.append(calc_dist)
    tuc47_dist_nopm.append(calc_dist_nopm)
    
tuc47dis = []
tuc47dis_err = []
tuc47dis_nopm = []
tuc47dis_nopm_err = []

for i in range(len(tuc47_dist)):
    tuc47dis.append(np.median(tuc47_dist[i]))
    tuc47dis_err.append(util.mad(tuc47_dist[i]))
    tuc47dis_nopm.append(np.median(tuc47_dist_nopm[i]))
    tuc47dis_nopm_err.append(util.mad(tuc47_dist_nopm[i]))
    
### N362
n362_dist = []
n362_dist_nopm = []
for i in tqdm_notebook(range(len(n362)),desc='Star'):
    mu = np.sqrt(n362['GAIA_PMRA'][i]**2+n362['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    n362_dist.append(calc_dist)
    n362_dist_nopm.append(calc_dist_nopm)
    
n362dis = []
n362dis_err = []
n362dis_nopm = []
n362dis_nopm_err = []

for i in range(len(n362_dist)):
    n362dis.append(np.median(n362_dist[i]))
    n362dis_err.append(util.mad(n362_dist[i]))
    n362dis_nopm.append(np.median(n362_dist_nopm[i]))
    n362dis_nopm_err.append(util.mad(n362_dist_nopm[i]))
    
### SMC1
smc1_dist = []
smc1_dist_nopm = []
for i in tqdm_notebook(range(len(smc1)),desc='Star'):
    mu = np.sqrt(smc1['GAIA_PMRA'][i]**2+smc1['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc1_dist.append(calc_dist)
    smc1_dist_nopm.append(calc_dist_nopm)
    
smc1dis = []
smc1dis_err = []
smc1dis_nopm = []
smc1dis_nopm_err = []

for i in range(len(smc1_dist)):
    smc1dis.append(np.median(smc1_dist[i]))
    smc1dis_err.append(util.mad(smc1_dist[i]))
    smc1dis_nopm.append(np.median(smc1_dist_nopm[i]))
    smc1dis_nopm_err.append(util.mad(smc1_dist_nopm[i]))

### SMC2
smc2_dist = []
smc2_dist_nopm = []
for i in tqdm_notebook(range(len(smc2)),desc='Star'):
    mu = np.sqrt(smc2['GAIA_PMRA'][i]**2+smc2['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc2_dist.append(calc_dist)
    smc2_dist_nopm.append(calc_dist_nopm)
    
smc2dis = []
smc2dis_err = []
smc2dis_nopm = []
smc2dis_nopm_err = []

for i in range(len(smc2_dist)):
    smc2dis.append(np.median(smc2_dist[i]))
    smc2dis_err.append(util.mad(smc2_dist[i]))
    smc2dis_nopm.append(np.median(smc2_dist_nopm[i]))
    smc2dis_nopm_err.append(util.mad(smc2_dist_nopm[i]))
    
### SMC3
smc3_dist = []
smc3_dist_nopm = []
for i in tqdm_notebook(range(len(smc3)),desc='Star'):
    mu = np.sqrt(smc3['GAIA_PMRA'][i]**2+smc3['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc3_dist.append(calc_dist)
    smc3_dist_nopm.append(calc_dist_nopm)
    
smc3dis = []
smc3dis_err = []
smc3dis_nopm = []
smc3dis_nopm_err = []

for i in range(len(smc3_dist)):
    smc3dis.append(np.median(smc3_dist[i]))
    smc3dis_err.append(util.mad(smc3_dist[i]))
    smc3dis_nopm.append(np.median(smc3_dist_nopm[i]))
    smc3dis_nopm_err.append(util.mad(smc3_dist_nopm[i]))
    
### SMC4
smc4_dist = []
smc4_dist_nopm = []
for i in tqdm_notebook(range(len(smc4)),desc='Star'):
    mu = np.sqrt(smc4['GAIA_PMRA'][i]**2+smc4['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc4_dist.append(calc_dist)
    smc4_dist_nopm.append(calc_dist_nopm)
    
smc4dis = []
smc4dis_err = []
smc4dis_nopm = []
smc4dis_nopm_err = []

for i in range(len(smc4_dist)):
    smc4dis.append(np.median(smc4_dist[i]))
    smc4dis_err.append(util.mad(smc4_dist[i]))
    smc4dis_nopm.append(np.median(smc4_dist_nopm[i]))
    smc4dis_nopm_err.append(util.mad(smc4_dist_nopm[i]))

### SMC5
smc5_dist = []
smc5_dist_nopm = []
for i in tqdm_notebook(range(len(smc5)),desc='Star'):
    mu = np.sqrt(smc5['GAIA_PMRA'][i]**2+smc5['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc5_dist.append(calc_dist)
    smc5_dist_nopm.append(calc_dist_nopm)
    
smc5dis = []
smc5dis_err = []
smc5dis_nopm = []
smc5dis_nopm_err = []

for i in range(len(smc5_dist)):
    smc5dis.append(np.median(smc5_dist[i]))
    smc5dis_err.append(util.mad(smc5_dist[i]))
    smc5dis_nopm.append(np.median(smc5_dist_nopm[i]))
    smc5dis_nopm_err.append(util.mad(smc5_dist_nopm[i]))
    
### SMC6
smc6_dist = []
smc6_dist_nopm = []
for i in tqdm_notebook(range(len(smc6)),desc='Star'):
    mu = np.sqrt(smc6['GAIA_PMRA'][i]**2+smc6['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc6_dist.append(calc_dist)
    smc6_dist_nopm.append(calc_dist_nopm)
    
smc6dis = []
smc6dis_err = []
smc6dis_nopm = []
smc6dis_nopm_err = []

for i in range(len(smc6_dist)):
    smc6dis.append(np.median(smc6_dist[i]))
    smc6dis_err.append(util.mad(smc6_dist[i]))
    smc6dis_nopm.append(np.median(smc6_dist_nopm[i]))
    smc6dis_nopm_err.append(util.mad(smc6_dist_nopm[i]))
    
### SMC7
smc7_dist = []
smc7_dist_nopm = []
for i in tqdm_notebook(range(len(smc7)),desc='Star'):
    mu = np.sqrt(smc7['GAIA_PMRA'][i]**2+smc7['GAIA_PMDEC'][i]**2)
    
    calc_dist = []
    calc_dist_nopm = []
    for j in tqdm_notebook(range(100),desc='Iteration',leave=False):
        d = dist(mu,np.median(rc_pmmag),d0) + 1000*util.add_noise(0,27)/(4.74*mu)
        d_nopm = (dist(mu,util.add_noise(np.median(rc_pmmag),util.mad(rc_pmmag)),d0) + 
                  1000*util.add_noise(0,27)/(4.74*mu))
        
        calc_dist.append(d)
        calc_dist_nopm.append(d_nopm)
        
    smc7_dist.append(calc_dist)
    smc7_dist_nopm.append(calc_dist_nopm)
    
smc7dis = []
smc7dis_err = []
smc7dis_nopm = []
smc7dis_nopm_err = []

for i in range(len(smc7_dist)):
    smc7dis.append(np.median(smc7_dist[i]))
    smc7dis_err.append(util.mad(smc7_dist[i]))
    smc7dis_nopm.append(np.median(smc7_dist_nopm[i]))
    smc7dis_nopm_err.append(util.mad(smc7_dist_nopm[i]))
# Out:
# ...
# ...
# ...

# %%
dist_list = [tuc47dis,n362dis,smc1dis,smc2dis,smc3dis,smc4dis,smc5dis,smc6dis,smc7dis]
dist_list_nopm = [tuc47dis_nopm,n362dis_nopm,smc1dis_nopm,smc2dis_nopm,smc3dis_nopm,smc4dis_nopm,smc5dis_nopm,
                  smc6dis_nopm,smc7dis_nopm]
dist_label = ['47 Tuc','NGC 362','SMC 1','SMC 2','SMC 3','SMC 4','SMC 5','SMC 6','SMC 7']

fig,ax = plt.subplots(9,1,figsize=[8,40])

for i in range(len(ax)):
    ax[i].hist(np.asarray(dist_list[i])/1000.,density=True,bins=15,histtype='step',lw=3.0,color='k',
               label='{}'.format('tan+pm'))
    ax[i].hist(np.asarray(dist_list_nopm[i])/1000.,density=True,bins=15,histtype='step',lw=3.0,color='r',
               label='{}'.format('tan'))
    
    ax[i].set_ylim(top=0.1)
    ax[i].set_xlim(30,110)
    
    ax[i].legend(loc='upper right')
    ax[i].set_title(r'{} tan+pm {:.3f}; tan {:.3f}'.format(dist_label[i],util.mad(np.asarray(dist_list[i])/1000.),
                                                           util.mad(np.asarray(dist_list_nopm[i])/1000.)))
    
    ax[i].axvline(50,ls='--',c='b')
    ax[i].axvline(60,ls='--',c='b')
    ax[i].axvline(70,ls='--',c='b')
    
#     if i == 0:
#         ax[i].text(100,0.04,r'$d = \frac{v_t}{4.74|\vec{\mu}|}$')
#         ax[i].text(100,0.02,r'$d = d_0 \frac{|\vec{\mu}_0|}{|\vec{\mu}|}$')

plt.tight_layout(pad=0.)

plt.savefig('distveldisp.pdf',bbox_inches='tight')
plt.show()

# %%
dist_list_err = [tuc47dis_err,n362dis_err,smc1dis_err,smc2dis_err,smc3dis_err,smc4dis_err,smc5dis_err,smc6dis_err,
                 smc7dis_err]
dist_list_nopm_err = [tuc47dis_nopm_err,n362dis_nopm_err,smc1dis_nopm_err,smc2dis_nopm_err,
                       smc3dis_nopm_err,smc4dis_nopm_err,smc5dis_nopm_err,smc6dis_nopm_err,smc7dis_nopm_err]

fig,ax = plt.subplots(9,1,figsize=[8,40])

for i in range(len(ax)):
    ax[i].hist(np.asarray(dist_list_err[i])/1000.,density=True,bins=15,histtype='step',lw=3.0,color='k',
               label='{}'.format('tan+pm'))
    ax[i].hist(np.asarray(dist_list_nopm_err[i])/1000.,density=True,bins=15,histtype='step',lw=3.0,color='r',
               label='{}'.format('tan'))
    
    ax[i].set_ylim(top=1.5)
#     ax[i].set_xlim(30,110)
    
    ax[i].legend(loc='upper right')
    ax[i].set_title(r'{} Error'.format(dist_label[i]))
    
#     ax[i].axvline(50,ls='--',c='b')
#     ax[i].axvline(60,ls='--',c='b')
#     ax[i].axvline(70,ls='--',c='b')
    
#     if i == 0:
#         ax[i].text(100,0.04,r'$d = \frac{v_t}{4.74|\vec{\mu}|}$')
#         ax[i].text(100,0.02,r'$d = d_0 \frac{|\vec{\mu}_0|}{|\vec{\mu}|}$')

plt.tight_layout(pad=0.)

plt.savefig('distveldisp_err.pdf',bbox_inches='tight')
plt.show()

# %%
np.median(dis)-util.mad(dis)
# Out:
# 56937.07343954733

# %%
plt.hist(rc_pmmag)

# %% [markdown]
# <font size='45'>
#     <b>
#         Let's Look at Ages
#     </b>
# </font>

# %%
def find_ages(z1,z2,z3):
#good good
    # #     x1,x2,x3,x12,x13,x23,x1sq,x2sq,x3sq,x2cu
#     p = [9.38559303e+00,4.50640684e-02,-6.04245546e-02,-2.97525149e+00,1.89919586e-02,-5.42190398e-02,
#          1.09839708e-01,-5.88914872e-03,2.50980954e-02,8.74102230e-01,2.28289124e-02]
#     age = (p[0]+p[1]*z1+p[2]*z2+p[3]*z3+p[4]*np.multiply(z1,z2)+p[5]*np.multiply(z1,z3)+p[6]*np.multiply(z2,z3)+
#            p[7]*(z1**2)+p[8]*(z2**2)+p[9]*(z3**2)+p[10]*(z2**3))
    
    #x1,x2,x3,x12,x13,x23,x1sq,x2sq,x3sq,x2cu,x3cu
    p = [9.38631710e+00,4.57009017e-02,-5.98198867e-02,-2.99642242e+00,1.86921027e-02,-4.51165023e-02,
         1.10829968e-01,-5.93377185e-03,2.51457473e-02,7.98522275e-01,2.26643514e-02,4.00941011e-01]
    age = (p[0]+p[1]*z1+p[2]*z2+p[3]*z3+p[4]*np.multiply(z1,z2)+p[5]*np.multiply(z1,z3)+p[6]*np.multiply(z2,z3)+
           p[7]*(z1**2)+p[8]*(z2**2)+p[9]*(z3**2)+p[10]*(z2**3)+p[11]*(z3**3))

    return age

#calculate absolute mag
def absmag(magnitude,distance):
    '''
    - magnitude: apparent magnitude of star
    - distance: distance to star in kpc
    Calculate the absolute magnitude of star
    '''
    absm = []
    absm.append(magnitude-5.0*np.log10(distance*1000)+5.0)
    absm = np.squeeze(np.array(absm))
    return absm

def sal(MH,aM):
    '''
    Calculate the Salaris correction to the overall metallicity
    '''
    return MH + np.log(0.638*(10**(aM))+0.362)

# %%
### Get Solar Fractions
abd = {'C':8.39,'N':7.78,'O':8.66,'Mg':7.53,'Ca':6.31,'S':7.14,'Si':7.51,'Fe':7.45}
keys = list(abd.keys())

sol_2_H = []
for i in keys:
    sol_2_H.append(abd[i]-12.0)
    
sol_xm  = 10**np.asarray(sol_2_H)/sum(10**np.asarray(sol_2_H))

# %%
### PCA
from sklearn.decomposition import PCA, KernelPCA

age_dist = []
age_dist_nopm = []

data = np.array([parsec['logTe'],parsec['Ksmag'],parsec['MH'],parsec['logg']]).T
pca_transform = PCA(n_components=3).fit(data)

for i in tqdm_notebook(range(len(smc_nobloop)),desc='Done?'):
    
    # temperature
    teff = smc_nobloop['TEFF'][i]
    teff_err = smc_nobloop['TEFF_ERR'][i]
    
    # photometry 
    ra = smc_nobloop['RA'][i]
    dec = smc_nobloop['DEC'][i]
    ks = smc_nobloop['K'][i]
    ks_err = smc_nobloop['K_ERR'][i]
    ak = smc_nobloop['AK_TARG'][i]
    distance = dis[i]/1000.
    distance_err = dis_err[i]/1000.
    distance_nopm = dis_nopm[i]/1000.
    distance_nopm_err = dis_nopm_err[i]/1000.
    
    # abundances
    mh = smc_nobloop['M_H'][i]
    mh_err = smc_nobloop['M_H_ERR'][i]
    cfe = smc_nobloop['C_FE'][i]
    cfe_err = smc_nobloop['C_FE_ERR'][i]
    nfe = smc_nobloop['N_FE'][i]
    nfe_err = smc_nobloop['N_FE_ERR'][i]
    feh = smc_nobloop['FE_H'][i]
    feh_err = smc_nobloop['FE_H_ERR'][i]
    
    # surface gravity
    lgg = smc_nobloop['LOGG'][i]
    lgg_err = smc_nobloop['LOGG_ERR'][i]
    
    noise_ages = []
    new = []
    noise_ages_nopm = []
    new_nopm = []
    for j in range(750):
       
        # calculate noisy temperature
        teff_new = util.add_noise(teff,teff_err) 
        lgteff_new = np.log10(teff_new)
    
        # Calculate noisy K magnitude
#         _, _, dist = afunc.LMCdisk_cart(ra,dec)

        dist_new = util.add_noise(distance,distance_err)
        dist_new_nopm = util.add_noise(distance_nopm,distance_nopm_err)
        
        ks_new = util.add_noise(ks,ks_err)
            
        absK_new = absmag(ks_new,dist_new) - ak
        absK_new_nopm = absmag(ks_new,dist_new_nopm) - ak
            
        # Calculate noisy Salaris correction
        
        x_C_new = sol_xm[0]*10**(util.add_noise(cfe,cfe_err)+
                                 util.add_noise(feh,feh_err)-util.add_noise(mh,mh_err))
        x_N_new = sol_xm[1]*10**(util.add_noise(nfe,nfe_err)+
                                 util.add_noise(feh,feh_err)-util.add_noise(mh,mh_err))
        
        ffac_new = (x_C_new+x_N_new)/sum(sol_xm[0:2])
        
        mh_new = util.add_noise(mh,mh_err)
        
        # Calculate noisy surface gravity
        lgg_new = util.add_noise(lgg,lgg_err)
            
        # calculate noisy age
        new.append(np.array([lgteff_new,absK_new,sal(mh_new,ffac_new),lgg_new]))
        new_nopm.append(np.array([lgteff_new,absK_new_nopm,sal(mh_new,ffac_new),lgg_new]))
        
    zs = pca_transform.transform(np.asarray(np.squeeze(new)))
    zs_nopm = pca_transform.transform(np.asarray(np.squeeze(new_nopm)))

    for l in range(len(zs)):
        noise_ages.append(find_ages(zs[l][0],zs[l][1],zs[l][2]))
        noise_ages_nopm.append(find_ages(zs_nopm[l][0],zs_nopm[l][1],zs_nopm[l][2]))
    
    age_dist.append(noise_ages)
    age_dist_nopm.append(noise_ages_nopm)

parages = [] 
devs = []
parages_nopm = [] 
devs_nopm = []
for k in tqdm_notebook(range(len(age_dist))):
    devs.append(util.mad(age_dist[k]))
    parages.append(np.median(age_dist[k]))
    devs_nopm.append(util.mad(age_dist_nopm[k]))
    parages_nopm.append(np.median(age_dist_nopm[k]))
    
devs = np.asarray(devs)
parages = np.asarray(parages)
devs_nopm = np.asarray(devs_nopm)
parages_nopm = np.asarray(parages_nopm)

# %%
plt.hist(parages,histtype='step',color='k')
plt.axvline(np.log10(ageU))

# %%
matplotlib.rcParams.update({'font.size': 30})
plt.figure(figsize=[12,10])
plt.scatter(parages,devs,c=smc_nobloop['FE_H'],cmap='jet')
plt.colorbar()

# plt.ylim(0,0.25)
plt.ylim(top=0.5)
plt.xlim(7.5,12.35)

plt.axvline(np.log10(ageU))
plt.axvline(np.log10(10.5*10**9))

plt.title(r'Color as [Fe/H]')
plt.xlabel(r'Log(Age)')
plt.ylabel(r'Log(Age) Error')

# plt.savefig('age_err.pdf',bbox_inches='tight')
plt.show()

# %%
matplotlib.rcParams.update({'font.size': 30})
plt.figure(figsize=[12,10])
plt.scatter(10**np.asarray(parages),devs,c='k',zorder=0)
plt.scatter(10**np.asarray(parages_nopm),devs_nopm,c='r',zorder=1,alpha=0.5)
# plt.colorbar()

# plt.ylim(0,0.25)
plt.ylim(top=0.5)
plt.xlim(10**7.5,10**12.35)

plt.xscale('log')

plt.axvline(10**np.log10(ageU))
plt.axvline(10**np.log10(10.5*10**9))

plt.title(r'Color as [Fe/H]')
plt.xlabel(r'Age')
plt.ylabel(r'Log(Age) Error')

# plt.savefig('age_err.pdf',bbox_inches='tight')
plt.show()

# %%
westage = np.array([parages[tuc47_ind].tolist(),parages[n362_ind].tolist(),parages[smc1_ind].tolist(),
                    parages[smc2_ind].tolist(),parages[smc3_ind].tolist()])
westage_devs = np.array([devs[tuc47_ind].tolist(),devs[n362_ind].tolist(),devs[smc1_ind].tolist(),
                         devs[smc2_ind].tolist(),devs[smc3_ind].tolist()])

westage_nopm = np.array([parages_nopm[tuc47_ind].tolist(),parages_nopm[n362_ind].tolist(),
                    parages_nopm[smc1_ind].tolist(),parages_nopm[smc2_ind].tolist(),
                    parages_nopm[smc3_ind].tolist()])
westage_devs_nopm = np.array([devs_nopm[tuc47_ind].tolist(),devs_nopm[n362_ind].tolist(),
                              devs_nopm[smc1_ind].tolist(),devs_nopm[smc2_ind].tolist(),
                              devs_nopm[smc3_ind].tolist()])

matplotlib.rcParams.update({'font.size': 30})
plt.figure(figsize=[12,10])
# plt.scatter(10**np.asarray(parages),devs,c='k',zorder=0)
# plt.scatter(10**np.asarray(parages),devs,c='r',zorder=1,alpha=0.5)
for i in range(len(westage)):
    plt.scatter(10**np.asarray(westage[i]),westage_devs[i],color='k')
    plt.scatter(10**np.asarray(westage_nopm[i]),westage_devs_nopm[i],color='r')
# plt.colorbar()

# plt.ylim(0,0.25)
plt.ylim(top=0.5)
plt.xlim(10**7.5,10**12.35)

plt.xscale('log')

plt.axvline(10**np.log10(ageU))
plt.axvline(10**np.log10(10.5*10**9))

plt.title(r'Color as [Fe/H]')
plt.xlabel(r'Age')
plt.ylabel(r'Log(Age) Error')

# plt.savefig('age_err.pdf',bbox_inches='tight')
plt.show()

# %%
tage_dist = []
for i in tqdm_notebook(range(len(smc_nobloop)),desc='Done?'):
    
    # temperature
    teff = smc_nobloop['TEFF'][i]
    teff_err = smc_nobloop['TEFF_ERR'][i]
    
    # photometry 
    ra = smc_nobloop['RA'][i]
    dec = smc_nobloop['DEC'][i]
    ks = smc_nobloop['K'][i]
    ks_err = smc_nobloop['K_ERR'][i]
    ak = smc_nobloop['AK_TARG'][i]
    tdist = 60 #dis[i]/1000.
    tdist_err = dis_err[i]/1000.
    
    # abundances
    mh = smc_nobloop['M_H'][i]
    mh_err = smc_nobloop['M_H_ERR'][i]
    cfe = smc_nobloop['C_FE'][i]
    cfe_err = smc_nobloop['C_FE_ERR'][i]
    nfe = smc_nobloop['N_FE'][i]
    nfe_err = smc_nobloop['N_FE_ERR'][i]
    feh = smc_nobloop['FE_H'][i]
    feh_err = smc_nobloop['FE_H_ERR'][i]
    
    # surface gravity
    lgg = smc_nobloop['LOGG'][i]
    lgg_err = smc_nobloop['LOGG_ERR'][i]
    
    noise_ages = []
    new = []
    for j in range(750):
       
        # calculate noisy temperature
        teff_new = util.add_noise(teff,teff_err) 
        lgteff_new = np.log10(teff_new)
    
        # Calculate noisy K magnitude
#         _, _, dist = afunc.LMCdisk_cart(ra,dec)

        tdist_new = 60. #util.add_noise(tdist,tdist_err)
        
        ks_new = util.add_noise(ks,ks_err)
            
        absK_new = absmag(ks_new,tdist_new) - ak
            
        # Calculate noisy Salaris correction
        
        x_C_new = sol_xm[0]*10**(util.add_noise(cfe,cfe_err)+
                                 util.add_noise(feh,feh_err)-util.add_noise(mh,mh_err))
        x_N_new = sol_xm[1]*10**(util.add_noise(nfe,nfe_err)+
                                 util.add_noise(feh,feh_err)-util.add_noise(mh,mh_err))
        
        ffac_new = (x_C_new+x_N_new)/sum(sol_xm[0:2])
        
        mh_new = util.add_noise(mh,mh_err)
        
        # Calculate noisy surface gravity
        lgg_new = util.add_noise(lgg,lgg_err)
            
        # calculate noisy age
        new.append(np.array([lgteff_new,absK_new,sal(mh_new,ffac_new),lgg_new]))
        
    zs = pca_transform.transform(np.asarray(np.squeeze(new)))

    for l in range(len(zs)):
        noise_ages.append(find_ages(zs[l][0],zs[l][1],zs[l][2]))
    
    tage_dist.append(noise_ages)

tparages = [] 
tdevs = []
for k in tqdm_notebook(range(len(age_dist))):
    tdevs.append(util.mad(tage_dist[k]))
    tparages.append(np.median(tage_dist[k]))

# %%
matplotlib.rcParams.update({'font.size': 30})
plt.figure(figsize=[12,10])
plt.scatter(tparages,tdevs,c=smc_nobloop['FE_H'],cmap='jet')
plt.colorbar()

plt.ylim(0,0.25)
plt.xlim(7.5,12.35)

plt.axvline(np.log10(ageU))
plt.axvline(np.log10(10.5*10**9))

plt.title(r'Color as [Fe/H]')
plt.xlabel(r'Log(Age)')
plt.ylabel(r'Log(Age) Error')

# plt.savefig('age_err.pdf',bbox_inches='tight')
plt.show()
